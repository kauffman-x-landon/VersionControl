# %%
user_name = input('What is your name: ')
age = int(input('How old are you: '))
age_to_days = age*365

print(user_name, "is this many days old", age_to_days)
# Out:
# What is your name:  landon
# How old are you:  21
# landon is this many days old 7665
